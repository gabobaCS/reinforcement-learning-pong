# %%
from turtle import distance
from typing import Optional
import numpy as np
import gymnasium as gym


class GridWorldEnv(gym.Env):

    def __init__(self, size: int = 5):
        # The size of the square grid (5x5 by default)
        self.size = size

        # Initialize positions - will be set randomly in reset()
        # Using -1,-1 as "uninitialized" state
        self._agent_location = np.array([-1, -1], dtype=np.int32)
        self._target_location = np.array([-1, -1], dtype=np.int32)

        # Define what the agent can observe
        # Dict space gives us structured, human-readable observations
        self.observation_space = gym.spaces.Dict(
            {
                "agent": gym.spaces.Box(0, size - 1, shape=(2,), dtype=int),   # [x, y] coordinates
                "target": gym.spaces.Box(0, size - 1, shape=(2,), dtype=int),  # [x, y] coordinates
            }
        )

        # Define what actions are available (4 directions)
        self.action_space = gym.spaces.Discrete(4)

        # Map action numbers to actual movements on the grid
        # This makes the code more readable than using raw numbers
        self._action_to_direction = {
            0: np.array([1, 0]),   # Move right (positive x)
            1: np.array([0, 1]),   # Move up (positive y)
            2: np.array([-1, 0]),  # Move left (negative x)
            3: np.array([0, -1]),  # Move down (negative y)
        }

    def _get_obs(self):
        """Convert internal state to observation format.
        Returns:
            dict: Observation with agent and target positions
        """
        return {"agent": self._agent_location, "target": self._target_location}
    
    def _get_info(self):
        """Compute auxiliary information for debugging.

        Returns:
            dict: Info with distance between agent and target
        """
        return {
            "distance": np.linalg.norm(
                self._agent_location - self._target_location, ord=1
            )
        }
        
        
    def reset(self, seed: Optional[int] = None, options: Optional[dict] = None):
        """Start a new episode.

        Args:
            seed: Random seed for reproducible episodes
            options: Additional configuration (unused in this example)

        Returns:
            tuple: (observation, info) for the initial state
        """
        # IMPORTANT: Must call this first to seed the random number generator
        super().reset(seed=seed)

        # Randomly place the agent anywhere on the grid
        self._agent_location = self.np_random.integers(0, self.size, size=2, dtype=int)

        # Randomly place target, ensuring it's different from agent position
        self._target_location = self._agent_location
        while np.array_equal(self._target_location, self._agent_location):
            self._target_location = self.np_random.integers(
                0, self.size, size=2, dtype=int
            )

        observation = self._get_obs()
        info = self._get_info()

        return observation, info
    
    
    def step(self, action):
        """Execute one timestep within the environment.

        Args:
            action: The action to take (0-3 for directions)

        Returns:
            tuple: (observation, reward, terminated, truncated, info)
        """
        # Map the discrete action (0-3) to a movement direction
        direction = self._action_to_direction[action]

        # Update agent position, ensuring it stays within grid bounds
        # np.clip prevents the agent from walking off the edge
        self._agent_location = np.clip(
            self._agent_location + direction, 0, self.size - 1
        )

        # Check if agent reached the target
        terminated = np.array_equal(self._agent_location, self._target_location)

        # We don't use truncation in this simple environment
        # (could add a step limit here if desired)
        truncated = False

        # Simple reward structure: +1 for reaching target, 0 otherwise
        # Alternative: could give small negative rewards for each step to encourage efficiency
        # reward = 1 if terminated else 0
        
        distance = np.linalg.norm(self._agent_location - self._target_location)
        reward = 1 if terminated else -0.1 * distance

        observation = self._get_obs()
        info = self._get_info()

        return observation, reward, terminated, truncated, info

# %%
import gymnasium as gym
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from gymnasium.wrappers import FlattenObservation

# Create env and wrap for SB3
def make_env():
    env = GridWorldEnv(size=5)
    env = FlattenObservation(env)   # <---- CRITICAL
    return env

env = make_env()

# Optional: check it's valid
check_env(env)

# %%
from stable_baselines3 import PPO

model = PPO(
    policy="MlpPolicy",
    env=make_vec_env(make_env, n_envs=8),   # parallel envs = faster learning
    verbose=1,
    learning_rate=3e-4,
    n_steps=256,
    tensorboard_log="./ppo_logs/",
)

model.learn(50_000)  # 50k steps is enough for this environment

model.save("ppo_gridworld")
# Out:
# Using cpu device
# Logging to ./ppo_logs/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.7     |
# |    ep_rew_mean     | -13.3    |
# | time/              |          |
# |    fps             | 11575    |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55          |
# |    ep_rew_mean          | -15.2       |
# | time/                   |             |
# |    fps                  | 4804        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012815956 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0217      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.66        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0234     |
# |    value_loss           | 6.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | -4.68       |
# | time/                   |             |
# |    fps                  | 4027        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013616169 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 7.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.1        |
# |    ep_rew_mean          | -1.45       |
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018195339 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 6.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.79        |
# |    ep_rew_mean          | -0.515      |
# | time/                   |             |
# |    fps                  | 3542        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.023922548 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0438     |
# |    value_loss           | 3.13        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.27       |
# |    ep_rew_mean          | 0.0569     |
# | time/                   |            |
# |    fps                  | 3456       |
# |    iterations           | 6          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.03298061 |
# |    clip_fraction        | 0.397      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.287      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.608      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0542    |
# |    value_loss           | 1.4        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.46        |
# |    ep_rew_mean          | 0.266       |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.038564634 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.147       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0541     |
# |    value_loss           | 0.359       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.2         |
# |    ep_rew_mean          | 0.447       |
# | time/                   |             |
# |    fps                  | 3302        |
# |    iterations           | 8           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.056120355 |
# |    clip_fraction        | 0.347       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0556     |
# |    value_loss           | 0.139       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01        |
# |    ep_rew_mean          | 0.449       |
# | time/                   |             |
# |    fps                  | 3253        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.052482903 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0397      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 0.0507      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.58        |
# |    ep_rew_mean          | 0.544       |
# | time/                   |             |
# |    fps                  | 3232        |
# |    iterations           | 10          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.026587576 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.385      |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0325     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.52        |
# |    ep_rew_mean          | 0.558       |
# | time/                   |             |
# |    fps                  | 3194        |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010291884 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.32       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00292    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.0109      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.28        |
# |    ep_rew_mean          | 0.606       |
# | time/                   |             |
# |    fps                  | 3151        |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006031923 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.29       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00689     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.1         |
# |    ep_rew_mean          | 0.648       |
# | time/                   |             |
# |    fps                  | 3125        |
# |    iterations           | 13          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004221677 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.272      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00928     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00601    |
# |    value_loss           | 0.00627     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5         |
# |    ep_rew_mean          | 0.545       |
# | time/                   |             |
# |    fps                  | 3118        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005857585 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00638    |
# |    value_loss           | 0.00498     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.63        |
# |    ep_rew_mean          | 0.532       |
# | time/                   |             |
# |    fps                  | 3116        |
# |    iterations           | 15          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.003993678 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.245      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000207   |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00455    |
# |    value_loss           | 0.00464     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.11         |
# |    ep_rew_mean          | 0.642        |
# | time/                   |              |
# |    fps                  | 3090         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0048924675 |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00012     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0055      |
# |    value_loss           | 0.00414      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.06         |
# |    ep_rew_mean          | 0.658        |
# | time/                   |              |
# |    fps                  | 3060         |
# |    iterations           | 17           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0028007384 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00281     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 0.00363      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.09         |
# |    ep_rew_mean          | 0.639        |
# | time/                   |              |
# |    fps                  | 3041         |
# |    iterations           | 18           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0038664173 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.232       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0113      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0049      |
# |    value_loss           | 0.0032       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.72         |
# |    ep_rew_mean          | 0.491        |
# | time/                   |              |
# |    fps                  | 3022         |
# |    iterations           | 19           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0057795583 |
# |    clip_fraction        | 0.0648       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.228       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00924      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 0.00318      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.4          |
# |    ep_rew_mean          | 0.586        |
# | time/                   |              |
# |    fps                  | 3005         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0038139778 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00492      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 0.00255      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.48         |
# |    ep_rew_mean          | 0.577        |
# | time/                   |              |
# |    fps                  | 2990         |
# |    iterations           | 21           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0063556284 |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.218       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00556     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 0.00199      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.26        |
# |    ep_rew_mean          | 0.609       |
# | time/                   |             |
# |    fps                  | 2979        |
# |    iterations           | 22          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005440596 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.222      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.19         |
# |    ep_rew_mean          | 0.628        |
# | time/                   |              |
# |    fps                  | 2966         |
# |    iterations           | 23           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0028334882 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.023       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 0.00179      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56         |
# |    ep_rew_mean          | 0.543        |
# | time/                   |              |
# |    fps                  | 2955         |
# |    iterations           | 24           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0036846686 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.213       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00851     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00429     |
# |    value_loss           | 0.00151      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.36         |
# |    ep_rew_mean          | 0.592        |
# | time/                   |              |
# |    fps                  | 2948         |
# |    iterations           | 25           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0026139785 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.207       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00464     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 0.00131      |
# ------------------------------------------

# %%
from stable_baselines3.common.evaluation import evaluate_policy
# Evaluate the agent
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

# Enjoy trained agent
obs = env.reset()
obs
# Out:
# (array([3, 2, 2, 4]), {'distance': np.float64(3.0)})
